# %%
import pandas as pd

# %% [markdown]
# # Importando dados do brasileirão

# %%
df = pd.read_json('dados-brasileirao/data/brasileirao-2023.json', orient='')
df
# Out:
#                                                     0  \
# 1   {'clubs': {'home': 'Palmeiras', 'away': 'Cuiab...
# 2   {'clubs': {'home': 'Fluminense', 'away': 'Athl...
# 3   {'clubs': {'home': 'Fortaleza', 'away': 'Flumi...
# 4   {'clubs': {'home': 'Cruzeiro', 'away': 'Santos...
# 5   {'clubs': {'home': 'Internacional', 'away': 'A...
# 6   {'clubs': {'home': 'Bahia', 'away': 'Flamengo'...
# 7   {'clubs': {'home': 'Bahia', 'away': 'Goiás'}, ...
# 8   {'clubs': {'home': 'Athletico-PR', 'away': 'Gr...
# 9   {'clubs': {'home': 'Fortaleza', 'away': 'Bahia...
# 10  {'clubs': {'home': 'Coritiba', 'away': 'Santos...
# 11  {'clubs': {'home': 'Cruzeiro', 'away': 'Fortal...
# 12  {'clubs': {'home': 'Athletico-PR', 'away': 'Co...
# 13  {'clubs': {'home': 'São Paulo', 'away': 'Flumi...
# 14  {'clubs': {'home': 'Cuiabá', 'away': 'Bahia'},...
# 15  {'clubs': {'home': 'Botafogo', 'away': 'Bragan...
# 16  {'clubs': {'home': 'Palmeiras', 'away': 'Forta...
# ...
